# %% [markdown]
# # Sample Jupyter notebook
# This notebook illustrates running interactive code snippets in codespaces

# %%
import pandas as pd
data_file:str = 'data/taxi_tripdata.csv'
df:pd.DataFrame = pd.read_csv(data_file)

# %%
# include data with fare greater than $50
df[df['fare_amount'] > 50.0]
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 12         2  2021-06-07 15:15:47   2021-06-07 16:45:22                  N
# 13         2  2021-07-01 00:31:21   2021-07-01 01:06:09                  N
# 47         2  2021-07-01 04:24:05   2021-07-01 06:00:50                  N
# 52         2  2021-07-01 04:39:47   2021-07-01 05:05:16                  N
# 60         2  2021-07-01 05:06:24   2021-07-01 05:51:14                  N
# 61         2  2021-07-01 05:53:17   2021-07-01 06:31:59                  N
# 63         2  2021-07-01 06:00:57   2021-07-01 07:12:35                  N
# 70         2  2021-07-01 06:28:15   2021-07-02 06:17:23                  N
# 72         2  2021-07-01 06:22:58   2021-07-01 07:12:31                  N
# 76         2  2021-07-01 06:21:57   2021-07-01 07:05:02                  N
# 77         2  2021-07-01 06:37:19   2021-07-01 06:37:35                  N
# ...
